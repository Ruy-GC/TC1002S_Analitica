# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("peso-estatura-genero.csv")

# %%
value = df.values

# %%
dhombres = df.values[:5000]
dmujeres = df.values[5000:]
peso_h = dhombres[:,2]/2.2
peso_m = dmujeres[:,2]/2.2
altura_h = dhombres[:,1]*0.0254
altura_m = dmujeres[:,1]*0.0254

# %%
plt.hist(peso_h,7) #el numero son los bins del histograma
# Out:
# (array([  22.,  321., 1492., 2084.,  950.,  119.,   12.]),
#  array([51.31951790909091, 61.51995681168831, 71.7203957142857,
#         81.9208346168831, 92.1212735194805, 102.3217124220779,
#         112.52215132467529, 122.7225902272727], dtype=object),
#  <BarContainer object of 7 artists>)

# %%
plt.hist(peso_m,7)
# Out:
# (array([  13.,  239., 1041., 1974., 1351.,  350.,   32.]),
#  array([29.409148504545456, 38.34012817922078, 47.2711078538961,
#         56.202087528571425, 65.13306720324675, 74.06404687792207,
#         82.9950265525974, 91.92600622727271], dtype=object),
#  <BarContainer object of 7 artists>)

# %%
plt.hist(altura_h,7)
# Out:
# (array([  28.,  219., 1039., 1980., 1368.,  331.,   35.]),
#  array([1.4835353852220001, 1.5582543381460001, 1.63297329107,
#         1.707692243994, 1.7824111969179999, 1.8571301498419999,
#         1.9318491027659999, 2.00656805569], dtype=object),
#  <BarContainer object of 7 artists>)

# %%
plt.hist(altura_m,7)
# Out:
# (array([  37.,  296., 1290., 1921., 1157.,  279.,   20.]),
#  array([1.378283586582, 1.4476852857985714, 1.517086985015143,
#         1.5864886842317143, 1.6558903834482857, 1.7252920826648572,
#         1.7946937818814286, 1.864095481098], dtype=object),
#  <BarContainer object of 7 artists>)
